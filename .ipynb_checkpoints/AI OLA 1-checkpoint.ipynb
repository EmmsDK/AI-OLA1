# %% [markdown]
# # OLA 1 - Data Wrangling and Descriptive Statistics

# %% [markdown]
# The following OLA gives yu an opportinmuty to wokr on the first stages of a machine learning / AI project. It is a group project and is intended to give you a chance to practice using typical Numpy/Pandas/Matplotlib and Seaborn functions to prepare and visualize data using simple plots.

# %% [markdown]
# ## DUE DATE: Week 9 (26 February) hand in on Moodle

# %% [markdown]
# ### Task 1: Data Exploration and Cleaning

# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\dieky\anaconda3\lib\site-packages (0.3.8)
# Requirement already satisfied: packaging in c:\users\dieky\anaconda3\lib\site-packages (from kagglehub) (24.1)
# Requirement already satisfied: requests in c:\users\dieky\anaconda3\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\dieky\anaconda3\lib\site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dieky\anaconda3\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dieky\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dieky\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dieky\anaconda3\lib\site-packages (from requests->kagglehub) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\dieky\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sachinkumar62/datascience-job-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\dieky\.cache\kagglehub\datasets\sachinkumar62\datascience-job-data\versions\1

# %%
import pandas as pd

df = pd.read_csv("data_science_job.csv")

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# 2             STEM         5.0          NaN             NaN            83.0
# 3  Business Degree         0.0          NaN         Pvt Ltd            52.0
# 4             STEM        20.0        50-99  Funded Startup             8.0
#
#    target
# 0     1.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     0.0

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index    experience  training_hours  \
# count  19158.000000            18679.000000  19093.000000    18392.000000
# mean   16875.358179                0.828951      9.928036       65.185787
# std     9616.292592                0.123334      6.505268       59.885626
# min        1.000000                0.448000      0.000000        1.000000
# 25%     8554.250000                0.740000      4.000000       23.000000
# 50%    16982.500000                0.903000      9.000000       47.000000
# 75%    25169.750000                0.920000     16.000000       88.000000
# max    33380.000000                0.949000     20.000000      336.000000
#
#              target
# count  19158.000000
# mean       0.249348
# std        0.432647
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
# Lists each column type. Useful for letting us know how we can interpolate the different data.
# Numerical data can be interpolated with df.interpolate().
# Categorical data, object = string, can use the df.mode() to replace missing data with the most used value in the column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  18679 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  float64
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  training_hours          18392 non-null  float64
#  12  target                  19158 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.9+ MB

# %%
print(df.isnull().sum())  # Shows count of missing values per column
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
# Interpolates missing values of the type number. It calculates a fitting value within the current values and then adds it to a missing cell
df[df.select_dtypes(include=['number']).columns] = df.select_dtypes(include=['number']).interpolate(method='linear')

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# 2             STEM         5.0          NaN             NaN            83.0
# 3  Business Degree         0.0          NaN         Pvt Ltd            52.0
# 4             STEM        20.0        50-99  Funded Startup             8.0
#
#    target
# 0     1.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     0.0

# %%
# Gender is either male or NaN. Assuming NaN = female we can replace the values with 1 for male and 0 for female. The lambda expression does that.
df['gender'] = df['gender'].apply(lambda x: 1 if x == 'Male' else 0)
df['relevent_experience'] = df['relevent_experience'].apply(lambda x: 1 if x == 'Has relevent experience' else 0)

df.head(10)
# Out:
#    enrollee_id      city  city_development_index  gender  relevent_experience  \
# 0         8949  city_103                   0.920       1                    1
# 1        29725   city_40                   0.776       1                    0
# 2        11561   city_21                   0.624       0                    0
# 3        33241  city_115                   0.789       0                    0
# 4          666  city_162                   0.767       1                    1
# 5        21651  city_176                   0.764       0                    1
# 6        28806  city_160                   0.920       1                    1
# 7          402   city_46                   0.762       1                    1
# 8        27107  city_103                   0.920       1                    1
# 9          699  city_103                   0.920       0                    1
#
#   enrolled_university education_level major_discipline  experience  \
# 0       no_enrollment        Graduate             STEM        20.0
# 1       no_enrollment        Graduate             STEM        15.0
# 2    Full time course        Graduate             STEM         5.0
# 3                 NaN        Graduate  Business Degree         0.0
# 4       no_enrollment         Masters             STEM        20.0
# 5    Part time course        Graduate             STEM        11.0
# 6       no_enrollment     High School              NaN         5.0
# 7       no_enrollment        Graduate             STEM        13.0
# 8       no_enrollment        Graduate             STEM         7.0
# 9       no_enrollment        Graduate             STEM        17.0
#
#   company_size    company_type  training_hours  target
# 0          NaN             NaN            36.0     1.0
# 1        50-99         Pvt Ltd            47.0     0.0
# 2          NaN             NaN            83.0     0.0
# 3          NaN         Pvt Ltd            52.0     1.0
# 4        50-99  Funded Startup             8.0     0.0
# 5          NaN             NaN            24.0     1.0
# 6        50-99  Funded Startup            24.0     0.0
# 7          <10         Pvt Ltd            18.0     1.0
# 8        50-99         Pvt Ltd            46.0     1.0
# 9       10000+         Pvt Ltd           123.0     0.0

# %%
# replaces a missing value with the most common value in the column.
df['enrolled_university'].fillna(df['enrolled_university'].mode()[0], inplace=True)
df['education_level'].fillna(df['education_level'].mode()[0], inplace=True)
df['major_discipline'].fillna(df['major_discipline'].mode()[0], inplace=True)

df.head(15)
# Out:
# C:\Users\dieky\AppData\Local\Temp\ipykernel_36192\81817810.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['enrolled_university'].fillna(df['enrolled_university'].mode()[0], inplace=True)
# C:\Users\dieky\AppData\Local\Temp\ipykernel_36192\81817810.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['education_level'].fillna(df['education_level'].mode()[0], inplace=True)
# C:\Users\dieky\AppData\Local\Temp\ipykernel_36192\81817810.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['major_discipline'].fillna(df['major_discipline'].mode()[0], inplace=True)
#     enrollee_id      city  city_development_index  gender  \
# 0          8949  city_103                   0.920       1
# 1         29725   city_40                   0.776       1
# 2         11561   city_21                   0.624       0
# 3         33241  city_115                   0.789       0
# 4           666  city_162                   0.767       1
# 5         21651  city_176                   0.764       0
# 6         28806  city_160                   0.920       1
# 7           402   city_46                   0.762       1
# 8         27107  city_103                   0.920       1
# 9           699  city_103                   0.920       0
# 10        29452   city_21                   0.624       0
# 11        23853  city_103                   0.920       1
# 12        25619   city_61                   0.913       1
# 13         5826   city_21                   0.624       1
# 14         8722   city_21                   0.624       0
#
#     relevent_experience enrolled_university education_level major_discipline  \
# 0                     1       no_enrollment        Graduate             STEM
# 1                     0       no_enrollment        Graduate             STEM
# 2                     0    Full time course        Graduate             STEM
# 3                     0       no_enrollment        Graduate  Business Degree
# 4                     1       no_enrollment         Masters             STEM
# 5                     1    Part time course        Graduate             STEM
# 6                     1       no_enrollment     High School             STEM
# 7                     1       no_enrollment        Graduate             STEM
# 8                     1       no_enrollment        Graduate             STEM
# 9                     1       no_enrollment        Graduate             STEM
# 10                    0    Full time course     High School             STEM
# 11                    1       no_enrollment        Graduate             STEM
# 12                    1       no_enrollment        Graduate             STEM
# 13                    0       no_enrollment        Graduate             STEM
# 14                    0    Full time course     High School             STEM
#
#     experience company_size    company_type  training_hours  target
# 0         20.0          NaN             NaN            36.0     1.0
# 1         15.0        50-99         Pvt Ltd            47.0     0.0
# 2          5.0          NaN             NaN            83.0     0.0
# 3          0.0          NaN         Pvt Ltd            52.0     1.0
# 4         20.0        50-99  Funded Startup             8.0     0.0
# 5         11.0          NaN             NaN            24.0     1.0
# 6          5.0        50-99  Funded Startup            24.0     0.0
# 7         13.0          <10         Pvt Ltd            18.0     1.0
# 8          7.0        50-99         Pvt Ltd            46.0     1.0
# 9         17.0       10000+         Pvt Ltd           123.0     0.0
# 10         2.0          NaN             NaN            32.0     1.0
# 11         5.0    5000-9999         Pvt Ltd           108.0     0.0
# 12        20.0    1000-4999         Pvt Ltd            23.0     0.0
# 13         2.0          NaN             NaN            24.0     0.0
# 14         5.0          NaN             NaN            26.0     0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='experience', kde=True, hue='gender')
plt.title('Experience by gender')
plt.show()

# DET HER ER LORT DONT USE

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='training_hours', kde=True, hue='gender')
#sns.pairplot(data=df)
plt.title('Experience by gender')
plt.show()

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index        gender  \
# count  19158.000000            19158.000000  19158.000000
# mean   16875.358179                0.828923      0.690103
# std     9616.292592                0.122591      0.462463
# min        1.000000                0.448000      0.000000
# 25%     8554.250000                0.742000      0.000000
# 50%    16982.500000                0.899000      1.000000
# 75%    25169.750000                0.920000      1.000000
# max    33380.000000                0.949000      1.000000
#
#        relevent_experience    experience  training_hours        target
# count         19158.000000  19158.000000    19158.000000  19158.000000
# mean              0.719908      9.925906       65.145318      0.249348
# std               0.449056      6.498568       59.265101      0.432647
# min               0.000000      0.000000        1.000000      0.000000
# 25%               0.000000      4.000000       23.000000      0.000000
# 50%               1.000000      9.000000       47.750000      0.000000
# 75%               1.000000     16.000000       88.000000      0.000000
# max               1.000000     20.000000      336.000000      1.000000

# %% [markdown]
# ### Task 2: Feature Engineering and Descriptive Statistics

# %% [markdown]
# ### Task 3: Data Wrangling and Analysis

# %% [markdown]
# * A Jupyter notebook containing all the code used.
# * A short report (2-3 pages) summarizing the findings and insights from the exercises, including figures and tables as necessary. (This can but does not have to be done in LaTeX! It could be done in Markdown format inside the Jupyter Notebook)
# * Submit work to the hand-in folder via the Moodle course - it is a group report but please hand in individually with all group member names and group name easy to find.
